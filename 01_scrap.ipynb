# %%
import json

# %%
with open("eventseye.json") as f:
    data = json.load(f)

# %%
import pandas as pd
df = pd.DataFrame(columns=["Exhibition_Name", "Describe","Country","City", "Place"])

# %%
for i in range(0, len(data)):
    print(data[i])
# Out:
# {'Exhibition_Name': '', 'Describe': '', 'Country': '', 'City': '', 'Place': ''}
# {'Exhibition_Name': 'BRIDAL ASIA - NEW DELHI', 'Describe': 'Wedding Show. Bridal Asia brings to you a first-of-its kind exhibition with a handpicked collection of bridal couture, jewellery & accessories', 'Country': 'India', 'City': 'New Delhi ', 'Place': 'JW Marriott Hotel New Delhi Aerocity'}
# {'Exhibition_Name': 'SALON DU MARIAGE - LYON', 'Describe': 'Lyon Wedding Fair. New trends, the best providers in your region. Wedding dresses, costumes, jewelers, announcements, decoration, florists, wedding planner, hairstyles, accessories, caterers, photographers, videographers...', 'Country': 'France', 'City': 'Lyon ', 'Place': 'Eurexpo'}
# ...

# %%
for i in range(0, len(data)):
    currentItem = data[i]
    df.loc[i] = [data[i]["Exhibition_Name"],data[i]["Describe"], data[i]["Country"], data[i]["City"], data[i]["Place"] ]

# %%
df
# Out:
#                           Exhibition_Name  \
# 0
# 1                 BRIDAL ASIA - NEW DELHI
# 2                 SALON DU MARIAGE - LYON
# 3          SALON TENDANCE MARIAGE DE LYON
# 4                      LUXE PACK - MONACO
# ..                                    ...
# 181  LUXURY BRIDAL EXPO CHICAGO OAK BROOK
# 182                         NEW DESIGNERS
# 183                    JEWELRYEXPO. KAZAN
# 184                           SILVER GOLD
# 185                   WEST SHORE ART FAIR
#
#                                               Describe              Country  \
# 0
# 1    Wedding Show. Bridal Asia brings to you a firs...                India
# 2    Lyon Wedding Fair. New trends, the best provid...               France
# 3    Lyon wedding fair. During this weekend, more t...               France
# 4    Luxury Goods Packaging Exhibition. LUXE PACK M...               Monaco
# ..                                                 ...                  ...
# ...

# %%
df.isnull()
# Out:
#      Exhibition_Name  Describe  Country   City  Place
# 0              False     False    False  False  False
# 1              False     False    False  False  False
# 2              False     False    False  False  False
# 3              False     False    False  False  False
# 4              False     False    False  False  False
# ..               ...       ...      ...    ...    ...
# 181            False     False    False  False  False
# 182            False     False    False  False  False
# 183            False     False    False  False  False
# 184            False     False    False  False  False
# 185            False     False    False  False  False
#
# [186 rows x 5 columns]

# %%
jewelry_data = df.dropna()
jewelry_data.isnull().sum()
# Out:
# Exhibition_Name    0
# Describe           0
# Country            0
# City               0
# Place              0
# dtype: int64

# %%
import requests
from tqdm.auto import tqdm

# %%
from dsmlibrary.datanode import DataNode

# %%
dir_raw_id = 62

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
datanode.upload_file(directory_id=dir_raw_id, file_path='eventseye.json')
# Out:
#   0%|          | 0.00/56.8k [00:00<?, ?B/s]
# {'id': 197,
#  'msg': 'file eventseye.json create sucessful',
#  'path': 'nutnicha/DSI310-08/rawData/eventseye.json',
#  'uploaded': True}
